# %% [markdown]
# # LabScript bilingual Jupyter demo
# This notebook uses the same LabScript runtime as CLI and Obsidian.

# %%
# %load_ext pnp_lab.labscript.jupyter

# %%
# %%lab
# Язык="-РУС"
#
# функция квадрат(x):
#     вернуть x * x
#
# для i в диапазон(1, 6):
#     печать(i, квадрат(i))

# %%
# %%lab
# LangRule="-ENG"
# import sat
# let result = sat.solve(2, [[1, 2], [-1, 2]])
# print(result["sat"])
